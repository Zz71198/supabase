# %% [markdown]
# <a href="https://colab.research.google.com/github/Zz71198/supabase/blob/master/Proyecto_Programaci%C3%B3n_para_qu%C3%ADmicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Versión el LaTeX: https://www.overleaf.com/project/67b39df5808fdba51fbef949
#
# # Propuesta programación en python para químicos, módulo átomos y moléculas
#
# En la actualidad, la programación resulta ser de valiosa importancia en la química teórica y experimental, por ejemplo, solo basta mirar el premio nobel de Química del año 2024. La simulación de fenómenos químicos, el análisis de datos espectrópicos y el diseño de moléculas requieren cada vez más el uso de algoritmos computacionales. Esta propuestas busca completar el curso magistral de átomos y moléculas principalmente, aunque nos gustaría expandir esto a los distintos cursos del pregrado, permitiendo que los estudiantes adquieran habilidades computacionales aplicadas a la mecánica cuántica y química computacional.
#
# La inclusión de herramientas computacionales en el curso permite a los estudiantes:
#
# + Aplicar métodos numéricos a problemas químicos.
# + Visualizar conceptos de mecánica cuántica de forma interactiva.
# + Facilitar el procesamiento de datos moleculares y espectroscópicos
# + Desarrollar habilidades fundamentales para la química computacional y la investigación
# + COMPRENDER POR FIN ESTE CURSO :V
#
# ## Objetivos del módulo
#
# La integración de Python en este curso tiene como objetivo proporcionar a los estudiantes herramientas computacionales que complementen el aprendizaje de los conceptos cuánticos de la estructura y molécular.
#
# ## Objetivos de aprendizaje:
#
# 1. Comprensión de la importancia de la programación en la química y su papel en la simulación, predicción y análisis de datos moleculares.
#
# 2. Aprender y utilizar Python y sus paquetes para resolver problemas teóricos y experimentales en mecánica cuántica y química computacional.
#
# 3. Implementación de algoritmos y métodos numéricos para la resolución de la ecuación de Schrödinger y otros problemas relacionados con la estructura atómica y molecular.
#
# 4. Relacionar la teoría con la práctica, solucionando computacionalmente ejercicios planteados en clases magistrales o dejados por el docente.
#
# 5. Desarrolar el proyecto final, donde aplique Python en un problema químico
#
# ## Recursos didáticos y herramientas
#
# Para garantizar la correcta integración de la programación se requerirá el uso de software especializado, acceso a internet y recursos didácticos digitales.
#
# ### Materiales de referencia
#
#
# **Documentación oficial de las Librerías Utilizadas**
#
# Los estudiantes trabajarán con la documentación oficial de las herramientas que se emplearán en el curso:
#
# + NumPy: https://numpy.org/
# + SciPy: https://scipy.org/
# + SymPy: https://www.sympy.org/es/
# + Matplotlib: https://matplotlib.org/
# + Ploty: https://plotly.com/
# + RDKit: https://www.rdkit.org/docs/api-docs.html
# + ASE: https://wiki.fysik.dtu.dk/ase/
# + PySCF: https://pyscf.org/
#
# **Recursos en Línea**:
# + Google Classroom: Para compartir materiales y hacer seguimiento y/o actualización al curso.
#
# + Google Colab: Para la ejecución y desarrollo de los módulos computacionales sin necesidad de instalación de software adicional. (Los módulos o clases se desarrollarán tipo Coursera)
#
# **Bases de Datos Utilizadas**
#
# + NIST Atomic Spectra Database: Infromación espectroscópica de elementos.  https://www.nist.gov/pml/atomic-spectra-database
# + PubChem: Bases de datos de estructuras moléculares. https://pubchem.ncbi.nlm.nih.gov/
# + ChemSpider: Base de datos de estructuras moléculares. https://www.chemspider.com/
#
# > ***Nota:*** Estos recursos pueden variar durante la realización de lcurso
#
# **Foro de discusión**:
#
# Para fomentar la interacción entre los estudiantes y facilitar la resolución de dudas, **A CONVENIR CON EL PROFE**
#
# ## Cronograma del curso
#
#
# | **Semana** | **Tema Teórico (Clase Magistral - Martes y Jueves)** | **Módulo Computacional (Asincrónico, Complementario)** | **Objetivos de Aprendizaje** | **Resultados Esperados** |
# |-----------|------------------------------------------------------|------------------------------------------------|-----------------------------|--------------------------|
# | **1** | Introducción al curso. Importancia de la programación en química. | Configuración del entorno en Google Colab y primeros scripts en Python. | Entender la importancia de la computación en química y familiarizarse con Python. | Los estudiantes podrán ejecutar código básico en Google Colab. |
# | **2** | Operaciones matemáticas básicas y manejo de datos en química. | Introducción a `NumPy`, `Matplotlib`, `Pandas` y `SciPy` para cálculos químicos. | Aprender a realizar cálculos numéricos y representar gráficamente datos científicos. | Manejo de operaciones matemáticas y generación de gráficos en Python. |
# | **3** | Fallas de la física clásica y origen de la mecánica cuántica. | Simulación de la dualidad onda-partícula con Python. | Comprender la dualidad onda-partícula y su impacto en la mecánica cuántica. | Creación de gráficos de interferencia y ondas de materia. |
# | **4** | Ecuación de Schrödinger y sus soluciones. | Resolución numérica de la ecuación de Schrödinger en 1D (partícula en una caja). | Aplicar la ecuación de Schrödinger a sistemas simples. | Implementación computacional de la ecuación en Python. |
# | **5** | Interpretación de Born y el principio de incertidumbre. | Simulación de incertidumbre cuántica y dispersión en `x` y `p`. | Visualizar la interpretación probabilística de la función de onda. | Representación gráfica del principio de incertidumbre. |
# | **6** | Aplicaciones a sistemas simples: Partícula en caja 2D. | Resolución numérica de la ecuación de Schrödinger en 2D. | Extender el concepto de partícula en caja a dos dimensiones. | Simulación de estados cuánticos en 2D. |
# | **7** | Movimiento vibracional y oscilador armónico cuántico. | Cálculo de energías del oscilador armónico cuántico y representación gráfica de estados vibracionales. | Aplicar la ecuación de Schrödinger al oscilador armónico. | Simulación de estados vibracionales en Python. |
# | **8** | Movimiento rotacional y niveles de energía. | Visualización de niveles de energía rotacionales y espectros moleculares. | Aplicar principios de la mecánica cuántica a la rotación molecular. | Cálculo y visualización de espectros rotacionales. |
# | **9** | Estructura atómica: Átomos hidrogenoides y orbitales atómicos. | Gráficos 3D de orbitales `s`, `p`, `d`, `f`. | Representar visualmente los orbitales atómicos. | Generación de visualizaciones de orbitales electrónicos en Python. |
# | **10** | Estructura electrónica y aproximación orbital. | Simulación del espectro del hidrógeno y comparación con datos experimentales. | Relacionar los niveles de energía atómicos con los espectros de emisión. | Simulación computacional del espectro del hidrógeno. |
# | **11** | Enlace químico y orbital molecular. | Implementación del modelo de Hückel para moléculas pequeñas. | Aplicar el modelo de orbitales moleculares a enlaces químicos. | Resolución numérica del método Hückel en Python. |
# | **12** | Moléculas diatómicas homonucleares y heteronucleares. | Modelado computacional de estructuras moleculares con `RDKit`. | Aplicar la teoría cuántica a la descripción de moléculas diatómicas. | Construcción y visualización de moléculas en Python. |
# | **13** | Moléculas poliatómicas y modelos computacionales en química. | Cálculo de propiedades moleculares con `PySCF`. | Aplicar métodos computacionales para predecir propiedades moleculares. | Uso de `PySCF` para cálculos cuánticos en moléculas. |
# | **14** | Introducción a la química computacional. | Comparación entre métodos computacionales y resultados experimentales. | Explorar el papel de la química computacional en la predicción de propiedades. | Evaluación de modelos computacionales en química teórica. |
# | **15** | Presentación de proyectos finales. | Elaboración y entrega del proyecto final. | Aplicar lo aprendido en un problema químico real. | Implementación y presentación de un proyecto computacional. |
# | **16** | Evaluación y cierre del curso. | Retroalimentación y discusión de resultados. | Reflexionar sobre los aprendizajes obtenidos. | Discusión sobre aplicaciones futuras de la química computacional. |
#
#
# ## Metodología
#
# El módulo de Programación en Python para Químicos - Átomos y Moléculas se desarrollará de forma complementaria y asincrónica al curso magistral, permitiendo que los estudiantes trabajen en los módulos computacionales a su propio ritmo.
#
# Cada módulo está diseñado para reforzar los conceptos teóricos del curso facilitando su comprensión mediante la implementación de cálculos, simulacione y visualización de datos en Python.
#
# **Estructura del módlulo**
# + Modalidad: Asincrónica
# + Frecuencia: Cada semana se habilitará un módulo computacional alineado con los temas del curso magistral.
#
# **Desarrollo de los módulos**
#
# Cada módulo constará de:
#
# 1. Breve introducción teórica del concepto cuántico y/o cálculo abordado en el curso magistral
# 2. Ejercicio guiado en Python.
# 3. Actividad práctica, aquí el estudiante deberá implementar cálculos y/o simulaciones.
# 4. Si es posible algún ejemplo de aplicación real.
#
# ## Propuesta de evaluación
#
# Se sugiere que los estudiantes que completen el módulo computacional puedan optar por una calificación adicional en el curso magistral de Átomos y Moléculas.
#
#
# + Reemplazar una evaluación parcial dentro del curso magistral.
# + La finalización del curso otorga un bono de X% sobre la califiación final del curso magistral.
#
# Los requisitos para obtener la nota:
#
# + Completar todos los módulos computacionales.
# + Entregar el proyecto final en la semana 15, donde se aplique Python.
# + La califiación se basará en la correcta implementación del código, análisis de resultados y presentación del proyecto.
